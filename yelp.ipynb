# %%
import pandas as pd
import numpy as np

# %%
review_list = pd.read_csv("yelp_review_splitted.csv.gz")

# %%
review_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5261670 entries, 0 to 5261669
# Data columns (total 10 columns):
# review_id      object
# user_id        object
# business_id    object
# stars          int64
# date           object
# text           object
# useful         float64
# funny          float64
# cool           float64
# split          object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 401.4+ MB

# %%
review_list.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xk5KazJuFX_Ii2uZZgiGNA  oAG0osraEcPioVpdXQiP6Q  5j7BnXXvlS69uLVHrY9Upw
# 1  Cy1ELcR7Vkum6gyrfCS_BQ  0fKNIC3LK-DZWJfwYh3X9w  kn1moWlLuMgmnHIVyz2PQA
# 2  HWARCCJpSpbLde8Zu7B5cQ  -kqkEBW_6AR2CqehCDVRFA  DMmeFKsUuMl0kDy7Zd7W3A
# 3  J3qmPD3C-GzjOVz5jT_M4g  EBT_hlmfgAJF9dTFnWY_uA  UcIrRf2mWgqqlg-HNoDl0A
# 4  9EtVxB1LvlBknxNkTbsr0g  7no3XHKQXbFGziL_GBWHeg  Y40U2KXA3v-N_h-9F8Y_aQ
#
#    stars        date                                               text  \
# 0      1  2015-01-17  Experience horrible food was cold ordered the ...
# 1      1  2017-03-03  Sucks!!!! Paid for sauce to go on my chicken s...
# 2      1  2017-10-21  PLEASE READ‼\n\nI just experienced the crazies...
# 3      1  2017-06-08  I ordered chicken chow mein, vegetable eggroll...
# 4      1  2015-12-07  This place gets one star because I did not hav...
#
#    useful  funny  cool  split
# 0     1.0    0.0   0.0  train
# ...

# %%
import re

# Clean text
def preprocess_text(text):
    if text.__class__ != str:
        return pd.NaT
    
    text = text.lower()
    text = re.sub(r"([,.!?])", r" \1 ", text)
    text = re.sub(r"[^a-zA-Z,.!?']", r" ", text)
    return text

review_list.text = review_list.text.apply(preprocess_text)
review_list.dropna()
# Out:
#                       review_id                 user_id  \
# 0        xk5KazJuFX_Ii2uZZgiGNA  oAG0osraEcPioVpdXQiP6Q
# 1        Cy1ELcR7Vkum6gyrfCS_BQ  0fKNIC3LK-DZWJfwYh3X9w
# 2        HWARCCJpSpbLde8Zu7B5cQ  -kqkEBW_6AR2CqehCDVRFA
# 3        J3qmPD3C-GzjOVz5jT_M4g  EBT_hlmfgAJF9dTFnWY_uA
# 4        9EtVxB1LvlBknxNkTbsr0g  7no3XHKQXbFGziL_GBWHeg
# ...                         ...                     ...
# 5261664  8DNR4bcpoI2wTpkal00qzA  dsN5zLzdTJo8_IEQlmphmg
# 5261665  uBEyLSelFqKf5mziNPFBPQ  IWRiM8CXYzPqOUHOv8I6TQ
# 5261666  z6WjNL5YcGd8kYyMty2ucw  DegdHOgnjR_zu3mPaAnbeg
# 5261667  qIPPBm6yDtiUTc8pLYibJg  M5PVZNxladG-qHLhseaXnQ
# 5261668  TOKjJU6QWCm3NryZ5heJng  R742SmIZuhpZ5HM8BJZ1lQ
#
#                     business_id  stars        date  \
# 0        5j7BnXXvlS69uLVHrY9Upw      1  2015-01-17
# 1        kn1moWlLuMgmnHIVyz2PQA      1  2017-03-03
# 2        DMmeFKsUuMl0kDy7Zd7W3A      1  2017-10-21
# 3        UcIrRf2mWgqqlg-HNoDl0A      1  2017-06-08
# ...
